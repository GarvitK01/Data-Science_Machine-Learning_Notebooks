# %%
import tensorflow as tf
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import Normalizer, MinMaxScaler
import warnings
warnings.filterwarnings('ignore')

# %%
apple = pd.read_csv('Data/AAPL_2006-01-01_to_2018-01-01.csv', index_col = 'Date', parse_dates=['Date'])

# %%
apple.head(10)
# Out:
#              Open   High    Low  Close     Volume  Name
# Date
# 2006-01-03  10.34  10.68  10.32  10.68  201853036  AAPL
# 2006-01-04  10.73  10.85  10.64  10.71  155225609  AAPL
# 2006-01-05  10.69  10.70  10.54  10.63  112396081  AAPL
# 2006-01-06  10.75  10.96  10.65  10.90  176139334  AAPL
# 2006-01-09  10.96  11.03  10.82  10.86  168861224  AAPL
# 2006-01-10  10.89  11.70  10.83  11.55  570088246  AAPL
# 2006-01-11  11.98  12.11  11.80  11.99  373548882  AAPL
# 2006-01-12  12.14  12.34  11.95  12.04  320201966  AAPL
# 2006-01-13  12.14  12.29  12.09  12.23  194153393  AAPL
# 2006-01-17  12.24  12.34  11.98  12.10  209215265  AAPL

# %%
apple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3019 entries, 2006-01-03 to 2017-12-29
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    3019 non-null   float64
#  1   High    3019 non-null   float64
#  2   Low     3019 non-null   float64
#  3   Close   3019 non-null   float64
#  4   Volume  3019 non-null   int64
#  5   Name    3019 non-null   object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 165.1+ KB

# %%
np.sum(apple.isna(), axis = 0)
# Out:
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# Name      0
# dtype: int64

# %%
def plot_stocks(column):
    for i in range(2006, 2018):
        apple[str(i)][column].asfreq('d').plot()
    plt.title(f"{column}")
    plt.show()

# %%
plot_stocks("Open")
plot_stocks("Low")
plot_stocks("High")
plot_stocks("Close")

# %%
def plot_roll(column):
    rolling = apple[f"{column}"].rolling('100d').mean()
    apple[f"{column}"].plot(color = 'green')
    rolling.plot(color = 'yellow')
    plt.legend([f'{column}', f'Rolling Mean of {column} over a 100 days'])
    plt.show()

# %%
plot_roll("Open")
plot_roll("Low")
plot_roll("High")
plot_roll("Close")

# %%
def scale_data(train, column):
    
    sc = MinMaxScaler(feature_range=(0,1))
    train_data = train[column]
    
    train_prep = np.array([train_data.to_list()]).T
    train_norm = sc.fit_transform(train_prep)
    
    return train_norm

# %%
sc = MinMaxScaler(feature_range=(0, 1))
def load_data(datasetname, column, seq_len, days):

    data = datasetname.loc[:,column]

    sequence_length = seq_len + 1
    result = []

    for index in range(len(data) - sequence_length):
        result.append(data[index: index + sequence_length])

    result = normalise_data(result)

    result = np.array(result)

    val_split = round(0.9 * result.shape[0])
    train = result[:int(val_split), :]
    np.random.shuffle(train)
    
    X_train = train[:, :-days]
    y_train = train[:, -days:]
    X_test = result[int(val_split):, :-days]
    y_test = result[int(val_split):, -days:]

    X_train = np.reshape(X_train, (X_train.shape[0],X_train.shape[1], 1))
    X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1)) 


    return [X_train, y_train, X_test, y_test]

def normalise_data(data):

    normalised_data = []
    for stock in data:
        normalised = [((float(p) / float(stock[0])) - 1) for p in stock]
        normalised_data.append(normalised)
    return normalised_data

# %%
X_train, y_train, X_test, y_test = load_data(apple, "Open", 100, 1)

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((2626, 100, 1), (2626, 1), (292, 100, 1), (292, 1))

# %%
def create_model(shape):
    
    model = tf.keras.models.Sequential()
    
    model.add(tf.keras.layers.LSTM(30, return_sequences = True, input_shape = (shape, 1)))
    model.add(tf.keras.layers.Dropout(0.2))
    model.add(tf.keras.layers.LSTM(45, return_sequences = True))
    model.add(tf.keras.layers.Dropout(0.2))
    model.add(tf.keras.layers.LSTM(50, return_sequences = False))
    model.add(tf.keras.layers.Dropout(0.2))
    model.add(tf.keras.layers.Dense(14, activation = 'linear'))
    
    return model

# %%
model = create_model(X_train.shape[1])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100, 30)           3840
# _________________________________________________________________
# dropout (Dropout)            (None, 100, 30)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100, 45)           13680
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100, 45)           0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 50)                19200
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense (Dense)                (None, 14)                714
# =================================================================
# Total params: 37,434
# Trainable params: 37,434
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss = 'mse', optimizer = 'Adam')

# %%
def train_predict(model, name, sequence, days):
    
    """
    model: model used for training
    name: Name of stock characteristic
    sequence: Number of prior days to take into account
    days: Prediction days
    """
    
    X_train, y_train, X_test, y_test = load_data(apple, name, sequence, days)
    
    model.fit(X_train, y_train, batch_size = 64, epochs = 45, validation_data = (X_test, y_test))
    
    test_preds = model.predict(X_test)
    
    plt.title(f"Real (Red) vs Predictions(Blue): {name}")
    p1 = plt.plot(y_test, color = 'r')
    p2 = plt.plot(test_preds, color = 'c')

# %%
train_predict(model, "Close", 100, 14)
# Out:
# Epoch 1/45
# WARNING:tensorflow:Model was constructed with shape (None, 100, 1) for input Tensor("lstm_input:0", shape=(None, 100, 1), dtype=float32), but it was called on an input with incompatible shape (None, 87, 1).
# WARNING:tensorflow:Model was constructed with shape (None, 100, 1) for input Tensor("lstm_input:0", shape=(None, 100, 1), dtype=float32), but it was called on an input with incompatible shape (None, 87, 1).
# 42/42 [==============================] - ETA: 0s - loss: 0.0258WARNING:tensorflow:Model was constructed with shape (None, 100, 1) for input Tensor("lstm_input:0", shape=(None, 100, 1), dtype=float32), but it was called on an input with incompatible shape (None, 87, 1).
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0258 - val_loss: 0.0029
# Epoch 2/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0107 - val_loss: 0.0040
# Epoch 3/45
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0096 - val_loss: 0.0022
# Epoch 4/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0080 - val_loss: 0.0028
# Epoch 5/45
# 42/42 [==============================] - 1s 15ms/step - loss: 0.0081 - val_loss: 0.0020
# Epoch 6/45
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0075 - val_loss: 0.0019
# Epoch 7/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0070 - val_loss: 0.0018
# Epoch 8/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0070 - val_loss: 0.0019
# Epoch 9/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0067 - val_loss: 0.0018
# Epoch 10/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0067 - val_loss: 0.0031
# Epoch 11/45
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0068 - val_loss: 0.0017
# Epoch 12/45
# 42/42 [==============================] - 1s 13ms/step - loss: 0.0062 - val_loss: 0.0023
# Epoch 13/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0062 - val_loss: 0.0018
# Epoch 14/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0059 - val_loss: 0.0018
# Epoch 15/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0059 - val_loss: 0.0016
# Epoch 16/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0058 - val_loss: 0.0021
# Epoch 17/45
# 42/42 [==============================] - 1s 13ms/step - loss: 0.0058 - val_loss: 0.0016
# Epoch 18/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0061 - val_loss: 0.0020
# Epoch 19/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0058 - val_loss: 0.0015
# Epoch 20/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0057 - val_loss: 0.0016
# Epoch 21/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0054 - val_loss: 0.0017
# Epoch 22/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0053 - val_loss: 0.0015
# Epoch 23/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0053 - val_loss: 0.0015
# Epoch 24/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0052 - val_loss: 0.0016
# Epoch 25/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0055 - val_loss: 0.0017
# Epoch 26/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0054 - val_loss: 0.0014
# Epoch 27/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0052 - val_loss: 0.0018
# Epoch 28/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0057 - val_loss: 0.0017
# Epoch 29/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0051 - val_loss: 0.0015
# Epoch 30/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0051 - val_loss: 0.0014
# Epoch 31/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0054 - val_loss: 0.0014
# Epoch 32/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0051 - val_loss: 0.0016
# Epoch 33/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0051 - val_loss: 0.0016
# Epoch 34/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0051 - val_loss: 0.0015
# Epoch 35/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0050 - val_loss: 0.0015
# Epoch 36/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0050 - val_loss: 0.0015
# Epoch 37/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0049 - val_loss: 0.0014
# Epoch 38/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0049 - val_loss: 0.0014
# Epoch 39/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0053 - val_loss: 0.0013
# Epoch 40/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0051 - val_loss: 0.0014
# Epoch 41/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0049 - val_loss: 0.0014
# Epoch 42/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0047 - val_loss: 0.0013
# Epoch 43/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0049 - val_loss: 0.0014
# Epoch 44/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0049 - val_loss: 0.0015
# Epoch 45/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0050 - val_loss: 0.0017
# WARNING:tensorflow:Model was constructed with shape (None, 100, 1) for input Tensor("lstm_input:0", shape=(None, 100, 1), dtype=float32), but it was called on an input with incompatible shape (None, 87, 1).

# %%
train_predict(model, "High", 100, 14)
# Out:
# Epoch 1/45
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0047 - val_loss: 0.0014
# Epoch 2/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0045 - val_loss: 0.0013
# Epoch 3/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0044 - val_loss: 0.0013
# Epoch 4/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0044 - val_loss: 0.0012
# Epoch 5/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0045 - val_loss: 0.0014
# Epoch 6/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0044 - val_loss: 0.0013
# Epoch 7/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0043 - val_loss: 0.0012
# Epoch 8/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0043 - val_loss: 0.0017
# Epoch 9/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0045 - val_loss: 0.0014
# Epoch 10/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0044 - val_loss: 0.0013
# Epoch 11/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0046 - val_loss: 0.0014
# Epoch 12/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0044 - val_loss: 0.0013
# Epoch 13/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0046 - val_loss: 0.0013
# Epoch 14/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0044 - val_loss: 0.0013
# Epoch 15/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0043 - val_loss: 0.0013
# Epoch 16/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0043 - val_loss: 0.0014
# Epoch 17/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0043 - val_loss: 0.0014
# Epoch 18/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0042 - val_loss: 0.0014
# Epoch 19/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0043 - val_loss: 0.0012
# Epoch 20/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0043 - val_loss: 0.0013
# Epoch 21/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0043 - val_loss: 0.0014
# Epoch 22/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0043 - val_loss: 0.0012
# Epoch 23/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0043 - val_loss: 0.0013
# Epoch 24/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0042 - val_loss: 0.0013
# Epoch 25/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0041 - val_loss: 0.0013
# Epoch 26/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0043 - val_loss: 0.0014
# Epoch 27/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0042 - val_loss: 0.0013
# Epoch 28/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0042 - val_loss: 0.0013
# Epoch 29/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0041 - val_loss: 0.0012
# Epoch 30/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0044 - val_loss: 0.0014
# Epoch 31/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0043 - val_loss: 0.0013
# Epoch 32/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0043 - val_loss: 0.0015
# Epoch 33/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0043 - val_loss: 0.0012
# Epoch 34/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0042 - val_loss: 0.0014
# Epoch 35/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0044 - val_loss: 0.0014
# Epoch 36/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0042 - val_loss: 0.0014
# Epoch 37/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0043 - val_loss: 0.0013
# Epoch 38/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0043 - val_loss: 0.0017
# Epoch 39/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0043 - val_loss: 0.0012
# Epoch 40/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0042 - val_loss: 0.0016
# Epoch 41/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0045 - val_loss: 0.0017
# Epoch 42/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0043 - val_loss: 0.0012
# Epoch 43/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0042 - val_loss: 0.0013
# Epoch 44/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0042 - val_loss: 0.0014
# Epoch 45/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0042 - val_loss: 0.0012

# %%
train_predict(model, "Open", 100, 14)
# Out:
# Epoch 1/45
# 42/42 [==============================] - 1s 12ms/step - loss: 0.0046 - val_loss: 0.0013
# Epoch 2/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0045 - val_loss: 0.0013
# Epoch 3/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0045 - val_loss: 0.0013
# Epoch 4/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0045 - val_loss: 0.0015
# Epoch 5/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0045 - val_loss: 0.0013
# Epoch 6/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0045 - val_loss: 0.0013
# Epoch 7/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0044 - val_loss: 0.0015
# Epoch 8/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0046 - val_loss: 0.0013
# Epoch 9/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0044 - val_loss: 0.0015
# Epoch 10/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0049 - val_loss: 0.0013
# Epoch 11/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0044 - val_loss: 0.0013
# Epoch 12/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0043 - val_loss: 0.0014
# Epoch 13/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0045 - val_loss: 0.0013
# Epoch 14/45
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0045 - val_loss: 0.0013
# Epoch 15/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0044 - val_loss: 0.0013
# Epoch 16/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0044 - val_loss: 0.0014
# Epoch 17/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0045 - val_loss: 0.0013
# Epoch 18/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0044 - val_loss: 0.0016
# Epoch 19/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0045 - val_loss: 0.0012
# Epoch 20/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0047 - val_loss: 0.0014
# Epoch 21/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0045 - val_loss: 0.0013
# Epoch 22/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0044 - val_loss: 0.0013
# Epoch 23/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0044 - val_loss: 0.0014
# Epoch 24/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0045 - val_loss: 0.0012
# Epoch 25/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0044 - val_loss: 0.0014
# Epoch 26/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0045 - val_loss: 0.0014
# Epoch 27/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0044 - val_loss: 0.0013
# Epoch 28/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0044 - val_loss: 0.0012
# Epoch 29/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0043 - val_loss: 0.0014
# Epoch 30/45
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0044 - val_loss: 0.0017
# Epoch 31/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0045 - val_loss: 0.0012
# Epoch 32/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0050 - val_loss: 0.0012
# Epoch 33/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0045 - val_loss: 0.0017
# Epoch 34/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0046 - val_loss: 0.0012
# Epoch 35/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0044 - val_loss: 0.0013
# Epoch 36/45
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0044 - val_loss: 0.0013
# Epoch 37/45
# 42/42 [==============================] - 1s 21ms/step - loss: 0.0045 - val_loss: 0.0012
# Epoch 38/45
# 42/42 [==============================] - 1s 14ms/step - loss: 0.0043 - val_loss: 0.0013
# Epoch 39/45
# 42/42 [==============================] - 1s 13ms/step - loss: 0.0045 - val_loss: 0.0013
# Epoch 40/45
# 42/42 [==============================] - 1s 16ms/step - loss: 0.0043 - val_loss: 0.0014
# Epoch 41/45
# 42/42 [==============================] - 1s 12ms/step - loss: 0.0044 - val_loss: 0.0012
# Epoch 42/45
# 42/42 [==============================] - 1s 15ms/step - loss: 0.0044 - val_loss: 0.0012
# Epoch 43/45
# 42/42 [==============================] - 1s 14ms/step - loss: 0.0044 - val_loss: 0.0013
# Epoch 44/45
# 42/42 [==============================] - 1s 13ms/step - loss: 0.0045 - val_loss: 0.0013
# Epoch 45/45
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0044 - val_loss: 0.0016
